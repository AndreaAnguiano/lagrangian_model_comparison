# %% [markdown]
# # Initialize the Model

# %% [markdown]
# We initialize the model to begin on New Years Day 2015 and run for 3 days:

# %%
from gnome.model import Model
from datetime import datetime, timedelta
start_time = datetime(2015, 1, 1, 0, 0)
model = Model(start_time=start_time,duration=timedelta(days=10), time_step = 60* 15) #seconds

# %% [markdown]
# # Create and Add a Map

# %% [markdown]
# Create a very simple map: all water with a polygon of latitude/longitude points to specify the map bounds:

# %%
from gnome.map import GnomeMap
model.map = GnomeMap(map_bounds=((-145,48), (-145,49), (-142,49), (-142,48)))

# %% [markdown]
# # Create and Add a Mover

# %% [markdown]
# Now we will create some simple movers and add them to the model. We use the SimpleMover class to specify a 0.5 m/s eastward current and also the RandomMover class to simulate spreading due to turbulent motions:

# %%
from gnome.movers import SimpleMover, RandomMover
velocity = (.5,0,0) #(u,v,w) in m/s
uniform_vel_mover = SimpleMover(velocity)
random_mover = RandomMover()

model.movers += uniform_vel_mover
model.movers += random_mover

# %% [markdown]
# # Create and Add a Spill

# %% [markdown]
# Spills in GNOME contain a release object which specifies the details of the release (e.g. where, when, how many elements). They also contain an element_type object which provides information on the type of substance spilled. For a conservative substance (i.e. one with no change in properties over time) we can use the default None value for element_type.
#
# We’ll use a simple release class which can be used for an instantaneous or continuous release which can occur at a single point, or over a line. (Here we set a instantaneous spill at a point in the middle of the map):

# %%
from gnome.spill import PointLineRelease, Spill
release = PointLineRelease(release_time=start_time,start_position=(-144,48.5,0),num_elements=1000)
spill = Spill(release)
model.spills += spill

# %% [markdown]
# # Create and Add an Outputter

# %% [markdown]
# Outputters allow us to save our model run results. Options include saving images at specified model time steps or saving all the particle information into a netCDF file for further analysis.
#
# Here we use the Renderer class to save an image every 6 hours. We specify the bounding box of the rendered map to be the same as those specified when we created the map object. The default is to save files into the working directory:

# %%
from gnome.outputters import Renderer
renderer = Renderer(output_timestep=timedelta(hours=6),map_BB=((-145,48), (-145,49), (-142,49), (-142,48)))

model.outputters += renderer

# %% [markdown]
# # Run the model

# %% [markdown]
# The model can be run by stepping through individual timesteps (e.g. if we want to see results along the way) or we can do a full run:

# %%
model.full_run()
# Out:
# Starting animation
# Starting animation
# Starting animation
# Starting animation
# Starting animation
# Starting animation
# [{'Renderer': {'image_filename': './foreground_00000.png',
#    'time_stamp': datetime.datetime(2015, 1, 1, 0, 0)},
#   'step_num': 0,
#   'valid': True},
#  {'step_num': 1},
#  {'step_num': 2},
#  {'step_num': 3},
#  {'step_num': 4},
#  {'step_num': 5},
#  {'step_num': 6},
#  {'step_num': 7},
#  {'step_num': 8},
#  {'step_num': 9},
#  {'step_num': 10},
#  {'step_num': 11},
#  {'step_num': 12},
#  {'step_num': 13},
#  {'step_num': 14},
#  {'step_num': 15},
#  {'step_num': 16},
#  {'step_num': 17},
#  {'step_num': 18},
#  {'step_num': 19},
#  {'step_num': 20},
#  {'step_num': 21},
#  {'step_num': 22},
#  {'step_num': 23},
#  {'Renderer': {'image_filename': './foreground_00024.png',
#    'time_stamp': datetime.datetime(2015, 1, 1, 6, 0)},
#   'step_num': 24,
#   'valid': True},
#  {'step_num': 25},
#  {'step_num': 26},
#  {'step_num': 27},
#  {'step_num': 28},
#  {'step_num': 29},
#  {'step_num': 30},
#  {'step_num': 31},
#  {'step_num': 32},
#  {'step_num': 33},
#  {'step_num': 34},
#  {'step_num': 35},
#  {'step_num': 36},
#  {'step_num': 37},
#  {'step_num': 38},
#  {'step_num': 39},
#  {'step_num': 40},
#  {'step_num': 41},
#  {'step_num': 42},
#  {'step_num': 43},
#  {'step_num': 44},
#  {'step_num': 45},
#  {'step_num': 46},
#  {'step_num': 47},
#  {'Renderer': {'image_filename': './foreground_00048.png',
#    'time_stamp': datetime.datetime(2015, 1, 1, 12, 0)},
#   'step_num': 48,
#   'valid': True},
#  {'step_num': 49},
#  {'step_num': 50},
#  {'step_num': 51},
#  {'step_num': 52},
#  {'step_num': 53},
#  {'step_num': 54},
#  {'step_num': 55},
#  {'step_num': 56},
#  {'step_num': 57},
#  {'step_num': 58},
#  {'step_num': 59},
#  {'step_num': 60},
#  {'step_num': 61},
#  {'step_num': 62},
#  {'step_num': 63},
#  {'step_num': 64},
#  {'step_num': 65},
#  {'step_num': 66},
#  {'step_num': 67},
#  {'step_num': 68},
#  {'step_num': 69},
#  {'step_num': 70},
#  {'step_num': 71},
#  {'Renderer': {'image_filename': './foreground_00072.png',
#    'time_stamp': datetime.datetime(2015, 1, 1, 18, 0)},
#   'step_num': 72,
#   'valid': True},
#  {'step_num': 73},
#  {'step_num': 74},
#  {'step_num': 75},
#  {'step_num': 76},
#  {'step_num': 77},
#  {'step_num': 78},
#  {'step_num': 79},
#  {'step_num': 80},
#  {'step_num': 81},
#  {'step_num': 82},
#  {'step_num': 83},
#  {'step_num': 84},
#  {'step_num': 85},
#  {'step_num': 86},
#  {'step_num': 87},
#  {'step_num': 88},
#  {'step_num': 89},
#  {'step_num': 90},
#  {'step_num': 91},
#  {'step_num': 92},
#  {'step_num': 93},
#  {'step_num': 94},
#  {'step_num': 95},
#  {'Renderer': {'image_filename': './foreground_00096.png',
#    'time_stamp': datetime.datetime(2015, 1, 2, 0, 0)},
#   'step_num': 96,
#   'valid': True},
#  {'step_num': 97},
#  {'step_num': 98},
#  {'step_num': 99},
#  {'step_num': 100},
#  {'step_num': 101},
#  {'step_num': 102},
#  {'step_num': 103},
#  {'step_num': 104},
#  {'step_num': 105},
#  {'step_num': 106},
#  {'step_num': 107},
#  {'step_num': 108},
#  {'step_num': 109},
#  {'step_num': 110},
#  {'step_num': 111},
#  {'step_num': 112},
#  {'step_num': 113},
#  {'step_num': 114},
#  {'step_num': 115},
#  {'step_num': 116},
#  {'step_num': 117},
#  {'step_num': 118},
#  {'step_num': 119},
#  {'Renderer': {'image_filename': './foreground_00120.png',
#    'time_stamp': datetime.datetime(2015, 1, 2, 6, 0)},
#   'step_num': 120,
#   'valid': True},
#  {'step_num': 121},
#  {'step_num': 122},
#  {'step_num': 123},
#  {'step_num': 124},
#  {'step_num': 125},
#  {'step_num': 126},
#  {'step_num': 127},
#  {'step_num': 128},
#  {'step_num': 129},
#  {'step_num': 130},
#  {'step_num': 131},
#  {'step_num': 132},
#  {'step_num': 133},
#  {'step_num': 134},
#  {'step_num': 135},
#  {'step_num': 136},
#  {'step_num': 137},
#  {'step_num': 138},
#  {'step_num': 139},
#  {'step_num': 140},
#  {'step_num': 141},
#  {'step_num': 142},
#  {'step_num': 143},
#  {'Renderer': {'image_filename': './foreground_00144.png',
#    'time_stamp': datetime.datetime(2015, 1, 2, 12, 0)},
#   'step_num': 144,
#   'valid': True},
#  {'step_num': 145},
#  {'step_num': 146},
#  {'step_num': 147},
#  {'step_num': 148},
#  {'step_num': 149},
#  {'step_num': 150},
#  {'step_num': 151},
#  {'step_num': 152},
#  {'step_num': 153},
#  {'step_num': 154},
#  {'step_num': 155},
#  {'step_num': 156},
#  {'step_num': 157},
#  {'step_num': 158},
#  {'step_num': 159},
#  {'step_num': 160},
#  {'step_num': 161},
#  {'step_num': 162},
#  {'step_num': 163},
#  {'step_num': 164},
#  {'step_num': 165},
#  {'step_num': 166},
#  {'step_num': 167},
#  {'Renderer': {'image_filename': './foreground_00168.png',
#    'time_stamp': datetime.datetime(2015, 1, 2, 18, 0)},
#   'step_num': 168,
#   'valid': True},
#  {'step_num': 169},
#  {'step_num': 170},
#  {'step_num': 171},
#  {'step_num': 172},
#  {'step_num': 173},
#  {'step_num': 174},
#  {'step_num': 175},
#  {'step_num': 176},
#  {'step_num': 177},
#  {'step_num': 178},
#  {'step_num': 179},
#  {'step_num': 180},
#  {'step_num': 181},
#  {'step_num': 182},
#  {'step_num': 183},
#  {'step_num': 184},
#  {'step_num': 185},
#  {'step_num': 186},
#  {'step_num': 187},
#  {'step_num': 188},
#  {'step_num': 189},
#  {'step_num': 190},
#  {'step_num': 191},
#  {'Renderer': {'image_filename': './foreground_00192.png',
#    'time_stamp': datetime.datetime(2015, 1, 3, 0, 0)},
#   'step_num': 192,
#   'valid': True},
#  {'step_num': 193},
#  {'step_num': 194},
#  {'step_num': 195},
#  {'step_num': 196},
#  {'step_num': 197},
#  {'step_num': 198},
#  {'step_num': 199},
#  {'step_num': 200},
#  {'step_num': 201},
#  {'step_num': 202},
#  {'step_num': 203},
#  {'step_num': 204},
#  {'step_num': 205},
#  {'step_num': 206},
#  {'step_num': 207},
#  {'step_num': 208},
#  {'step_num': 209},
#  {'step_num': 210},
#  {'step_num': 211},
#  {'step_num': 212},
#  {'step_num': 213},
#  {'step_num': 214},
#  {'step_num': 215},
#  {'Renderer': {'image_filename': './foreground_00216.png',
#    'time_stamp': datetime.datetime(2015, 1, 3, 6, 0)},
#   'step_num': 216,
#   'valid': True},
#  {'step_num': 217},
#  {'step_num': 218},
#  {'step_num': 219},
#  {'step_num': 220},
#  {'step_num': 221},
#  {'step_num': 222},
#  {'step_num': 223},
#  {'step_num': 224},
#  {'step_num': 225},
#  {'step_num': 226},
#  {'step_num': 227},
#  {'step_num': 228},
#  {'step_num': 229},
#  {'step_num': 230},
#  {'step_num': 231},
#  {'step_num': 232},
#  {'step_num': 233},
#  {'step_num': 234},
#  {'step_num': 235},
#  {'step_num': 236},
#  {'step_num': 237},
#  {'step_num': 238},
#  {'step_num': 239},
#  {'Renderer': {'image_filename': './foreground_00240.png',
#    'time_stamp': datetime.datetime(2015, 1, 3, 12, 0)},
#   'step_num': 240,
#   'valid': True},
#  {'step_num': 241},
#  {'step_num': 242},
#  {'step_num': 243},
#  {'step_num': 244},
#  {'step_num': 245},
#  {'step_num': 246},
#  {'step_num': 247},
#  {'step_num': 248},
#  {'step_num': 249},
#  {'step_num': 250},
#  {'step_num': 251},
#  {'step_num': 252},
#  {'step_num': 253},
#  {'step_num': 254},
#  {'step_num': 255},
#  {'step_num': 256},
#  {'step_num': 257},
#  {'step_num': 258},
#  {'step_num': 259},
#  {'step_num': 260},
#  {'step_num': 261},
#  {'step_num': 262},
#  {'step_num': 263},
#  {'Renderer': {'image_filename': './foreground_00264.png',
#    'time_stamp': datetime.datetime(2015, 1, 3, 18, 0)},
#   'step_num': 264,
#   'valid': True},
#  {'step_num': 265},
#  {'step_num': 266},
#  {'step_num': 267},
#  {'step_num': 268},
#  {'step_num': 269},
#  {'step_num': 270},
#  {'step_num': 271},
#  {'step_num': 272},
#  {'step_num': 273},
#  {'step_num': 274},
#  {'step_num': 275},
#  {'step_num': 276},
#  {'step_num': 277},
#  {'step_num': 278},
#  {'step_num': 279},
#  {'step_num': 280},
#  {'step_num': 281},
#  {'step_num': 282},
#  {'step_num': 283},
#  {'step_num': 284},
#  {'step_num': 285},
#  {'step_num': 286},
#  {'step_num': 287},
#  {'Renderer': {'image_filename': './foreground_00288.png',
#    'time_stamp': datetime.datetime(2015, 1, 4, 0, 0)},
#   'step_num': 288,
#   'valid': True},
#  {'step_num': 289},
#  {'step_num': 290},
#  {'step_num': 291},
#  {'step_num': 292},
#  {'step_num': 293},
#  {'step_num': 294},
#  {'step_num': 295},
#  {'step_num': 296},
#  {'step_num': 297},
#  {'step_num': 298},
#  {'step_num': 299},
#  {'step_num': 300},
#  {'step_num': 301},
#  {'step_num': 302},
#  {'step_num': 303},
#  {'step_num': 304},
#  {'step_num': 305},
#  {'step_num': 306},
#  {'step_num': 307},
#  {'step_num': 308},
#  {'step_num': 309},
#  {'step_num': 310},
#  {'step_num': 311},
#  {'Renderer': {'image_filename': './foreground_00312.png',
#    'time_stamp': datetime.datetime(2015, 1, 4, 6, 0)},
#   'step_num': 312,
#   'valid': True},
#  {'step_num': 313},
#  {'step_num': 314},
#  {'step_num': 315},
#  {'step_num': 316},
#  {'step_num': 317},
#  {'step_num': 318},
#  {'step_num': 319},
#  {'step_num': 320},
#  {'step_num': 321},
#  {'step_num': 322},
#  {'step_num': 323},
#  {'step_num': 324},
#  {'step_num': 325},
#  {'step_num': 326},
#  {'step_num': 327},
#  {'step_num': 328},
#  {'step_num': 329},
#  {'step_num': 330},
#  {'step_num': 331},
#  {'step_num': 332},
#  {'step_num': 333},
#  {'step_num': 334},
#  {'step_num': 335},
#  {'Renderer': {'image_filename': './foreground_00336.png',
#    'time_stamp': datetime.datetime(2015, 1, 4, 12, 0)},
#   'step_num': 336,
#   'valid': True},
#  {'step_num': 337},
#  {'step_num': 338},
#  {'step_num': 339},
#  {'step_num': 340},
#  {'step_num': 341},
#  {'step_num': 342},
#  {'step_num': 343},
#  {'step_num': 344},
#  {'step_num': 345},
#  {'step_num': 346},
#  {'step_num': 347},
#  {'step_num': 348},
#  {'step_num': 349},
#  {'step_num': 350},
#  {'step_num': 351},
#  {'step_num': 352},
#  {'step_num': 353},
#  {'step_num': 354},
#  {'step_num': 355},
#  {'step_num': 356},
#  {'step_num': 357},
#  {'step_num': 358},
#  {'step_num': 359},
#  {'Renderer': {'image_filename': './foreground_00360.png',
#    'time_stamp': datetime.datetime(2015, 1, 4, 18, 0)},
#   'step_num': 360,
#   'valid': True},
#  {'step_num': 361},
#  {'step_num': 362},
#  {'step_num': 363},
#  {'step_num': 364},
#  {'step_num': 365},
#  {'step_num': 366},
#  {'step_num': 367},
#  {'step_num': 368},
#  {'step_num': 369},
#  {'step_num': 370},
#  {'step_num': 371},
#  {'step_num': 372},
#  {'step_num': 373},
#  {'step_num': 374},
#  {'step_num': 375},
#  {'step_num': 376},
#  {'step_num': 377},
#  {'step_num': 378},
#  {'step_num': 379},
#  {'step_num': 380},
#  {'step_num': 381},
#  {'step_num': 382},
#  {'step_num': 383},
#  {'Renderer': {'image_filename': './foreground_00384.png',
#    'time_stamp': datetime.datetime(2015, 1, 5, 0, 0)},
#   'step_num': 384,
#   'valid': True},
#  {'step_num': 385},
#  {'step_num': 386},
#  {'step_num': 387},
#  {'step_num': 388},
#  {'step_num': 389},
#  {'step_num': 390},
#  {'step_num': 391},
#  {'step_num': 392},
#  {'step_num': 393},
#  {'step_num': 394},
#  {'step_num': 395},
#  {'step_num': 396},
#  {'step_num': 397},
#  {'step_num': 398},
#  {'step_num': 399},
#  {'step_num': 400},
#  {'step_num': 401},
#  {'step_num': 402},
#  {'step_num': 403},
#  {'step_num': 404},
#  {'step_num': 405},
#  {'step_num': 406},
#  {'step_num': 407},
#  {'Renderer': {'image_filename': './foreground_00408.png',
#    'time_stamp': datetime.datetime(2015, 1, 5, 6, 0)},
#   'step_num': 408,
#   'valid': True},
#  {'step_num': 409},
#  {'step_num': 410},
#  {'step_num': 411},
#  {'step_num': 412},
#  {'step_num': 413},
#  {'step_num': 414},
#  {'step_num': 415},
#  {'step_num': 416},
#  {'step_num': 417},
#  {'step_num': 418},
#  {'step_num': 419},
#  {'step_num': 420},
#  {'step_num': 421},
#  {'step_num': 422},
#  {'step_num': 423},
#  {'step_num': 424},
#  {'step_num': 425},
#  {'step_num': 426},
#  {'step_num': 427},
#  {'step_num': 428},
#  {'step_num': 429},
#  {'step_num': 430},
#  {'step_num': 431},
#  {'Renderer': {'image_filename': './foreground_00432.png',
#    'time_stamp': datetime.datetime(2015, 1, 5, 12, 0)},
#   'step_num': 432,
#   'valid': True},
#  {'step_num': 433},
#  {'step_num': 434},
#  {'step_num': 435},
#  {'step_num': 436},
#  {'step_num': 437},
#  {'step_num': 438},
#  {'step_num': 439},
#  {'step_num': 440},
#  {'step_num': 441},
#  {'step_num': 442},
#  {'step_num': 443},
#  {'step_num': 444},
#  {'step_num': 445},
#  {'step_num': 446},
#  {'step_num': 447},
#  {'step_num': 448},
#  {'step_num': 449},
#  {'step_num': 450},
#  {'step_num': 451},
#  {'step_num': 452},
#  {'step_num': 453},
#  {'step_num': 454},
#  {'step_num': 455},
#  {'Renderer': {'image_filename': './foreground_00456.png',
#    'time_stamp': datetime.datetime(2015, 1, 5, 18, 0)},
#   'step_num': 456,
#   'valid': True},
#  {'step_num': 457},
#  {'step_num': 458},
#  {'step_num': 459},
#  {'step_num': 460},
#  {'step_num': 461},
#  {'step_num': 462},
#  {'step_num': 463},
#  {'step_num': 464},
#  {'step_num': 465},
#  {'step_num': 466},
#  {'step_num': 467},
#  {'step_num': 468},
#  {'step_num': 469},
#  {'step_num': 470},
#  {'step_num': 471},
#  {'step_num': 472},
#  {'step_num': 473},
#  {'step_num': 474},
#  {'step_num': 475},
#  {'step_num': 476},
#  {'step_num': 477},
#  {'step_num': 478},
#  {'step_num': 479},
#  {'Renderer': {'image_filename': './foreground_00480.png',
#    'time_stamp': datetime.datetime(2015, 1, 6, 0, 0)},
#   'step_num': 480,
#   'valid': True},
#  {'step_num': 481},
#  {'step_num': 482},
#  {'step_num': 483},
#  {'step_num': 484},
#  {'step_num': 485},
#  {'step_num': 486},
#  {'step_num': 487},
#  {'step_num': 488},
#  {'step_num': 489},
#  {'step_num': 490},
#  {'step_num': 491},
#  {'step_num': 492},
#  {'step_num': 493},
#  {'step_num': 494},
#  {'step_num': 495},
#  {'step_num': 496},
#  {'step_num': 497},
#  {'step_num': 498},
#  {'step_num': 499},
#  {'step_num': 500},
#  {'step_num': 501},
#  {'step_num': 502},
#  {'step_num': 503},
#  {'Renderer': {'image_filename': './foreground_00504.png',
#    'time_stamp': datetime.datetime(2015, 1, 6, 6, 0)},
#   'step_num': 504,
#   'valid': True},
#  {'step_num': 505},
#  {'step_num': 506},
#  {'step_num': 507},
#  {'step_num': 508},
#  {'step_num': 509},
#  {'step_num': 510},
#  {'step_num': 511},
#  {'step_num': 512},
#  {'step_num': 513},
#  {'step_num': 514},
#  {'step_num': 515},
#  {'step_num': 516},
#  {'step_num': 517},
#  {'step_num': 518},
#  {'step_num': 519},
#  {'step_num': 520},
#  {'step_num': 521},
#  {'step_num': 522},
#  {'step_num': 523},
#  {'step_num': 524},
#  {'step_num': 525},
#  {'step_num': 526},
#  {'step_num': 527},
#  {'Renderer': {'image_filename': './foreground_00528.png',
#    'time_stamp': datetime.datetime(2015, 1, 6, 12, 0)},
#   'step_num': 528,
#   'valid': True},
#  {'step_num': 529},
#  {'step_num': 530},
#  {'step_num': 531},
#  {'step_num': 532},
#  {'step_num': 533},
#  {'step_num': 534},
#  {'step_num': 535},
#  {'step_num': 536},
#  {'step_num': 537},
#  {'step_num': 538},
#  {'step_num': 539},
#  {'step_num': 540},
#  {'step_num': 541},
#  {'step_num': 542},
#  {'step_num': 543},
#  {'step_num': 544},
#  {'step_num': 545},
#  {'step_num': 546},
#  {'step_num': 547},
#  {'step_num': 548},
#  {'step_num': 549},
#  {'step_num': 550},
#  {'step_num': 551},
#  {'Renderer': {'image_filename': './foreground_00552.png',
#    'time_stamp': datetime.datetime(2015, 1, 6, 18, 0)},
#   'step_num': 552,
#   'valid': True},
#  {'step_num': 553},
#  {'step_num': 554},
#  {'step_num': 555},
#  {'step_num': 556},
#  {'step_num': 557},
#  {'step_num': 558},
#  {'step_num': 559},
#  {'step_num': 560},
#  {'step_num': 561},
#  {'step_num': 562},
#  {'step_num': 563},
#  {'step_num': 564},
#  {'step_num': 565},
#  {'step_num': 566},
#  {'step_num': 567},
#  {'step_num': 568},
#  {'step_num': 569},
#  {'step_num': 570},
#  {'step_num': 571},
#  {'step_num': 572},
#  {'step_num': 573},
#  {'step_num': 574},
#  {'step_num': 575},
#  {'Renderer': {'image_filename': './foreground_00576.png',
#    'time_stamp': datetime.datetime(2015, 1, 7, 0, 0)},
#   'step_num': 576,
#   'valid': True},
#  {'step_num': 577},
#  {'step_num': 578},
#  {'step_num': 579},
#  {'step_num': 580},
#  {'step_num': 581},
#  {'step_num': 582},
#  {'step_num': 583},
#  {'step_num': 584},
#  {'step_num': 585},
#  {'step_num': 586},
#  {'step_num': 587},
#  {'step_num': 588},
#  {'step_num': 589},
#  {'step_num': 590},
#  {'step_num': 591},
#  {'step_num': 592},
#  {'step_num': 593},
#  {'step_num': 594},
#  {'step_num': 595},
#  {'step_num': 596},
#  {'step_num': 597},
#  {'step_num': 598},
#  {'step_num': 599},
#  {'Renderer': {'image_filename': './foreground_00600.png',
#    'time_stamp': datetime.datetime(2015, 1, 7, 6, 0)},
#   'step_num': 600,
#   'valid': True},
#  {'step_num': 601},
#  {'step_num': 602},
#  {'step_num': 603},
#  {'step_num': 604},
#  {'step_num': 605},
#  {'step_num': 606},
#  {'step_num': 607},
#  {'step_num': 608},
#  {'step_num': 609},
#  {'step_num': 610},
#  {'step_num': 611},
#  {'step_num': 612},
#  {'step_num': 613},
#  {'step_num': 614},
#  {'step_num': 615},
#  {'step_num': 616},
#  {'step_num': 617},
#  {'step_num': 618},
#  {'step_num': 619},
#  {'step_num': 620},
#  {'step_num': 621},
#  {'step_num': 622},
#  {'step_num': 623},
#  {'Renderer': {'image_filename': './foreground_00624.png',
#    'time_stamp': datetime.datetime(2015, 1, 7, 12, 0)},
#   'step_num': 624,
#   'valid': True},
#  {'step_num': 625},
#  {'step_num': 626},
#  {'step_num': 627},
#  {'step_num': 628},
#  {'step_num': 629},
#  {'step_num': 630},
#  {'step_num': 631},
#  {'step_num': 632},
#  {'step_num': 633},
#  {'step_num': 634},
#  {'step_num': 635},
#  {'step_num': 636},
#  {'step_num': 637},
#  {'step_num': 638},
#  {'step_num': 639},
#  {'step_num': 640},
#  {'step_num': 641},
#  {'step_num': 642},
#  {'step_num': 643},
#  {'step_num': 644},
#  {'step_num': 645},
#  {'step_num': 646},
#  {'step_num': 647},
#  {'Renderer': {'image_filename': './foreground_00648.png',
#    'time_stamp': datetime.datetime(2015, 1, 7, 18, 0)},
#   'step_num': 648,
#   'valid': True},
#  {'step_num': 649},
#  {'step_num': 650},
#  {'step_num': 651},
#  {'step_num': 652},
#  {'step_num': 653},
#  {'step_num': 654},
#  {'step_num': 655},
#  {'step_num': 656},
#  {'step_num': 657},
#  {'step_num': 658},
#  {'step_num': 659},
#  {'step_num': 660},
#  {'step_num': 661},
#  {'step_num': 662},
#  {'step_num': 663},
#  {'step_num': 664},
#  {'step_num': 665},
#  {'step_num': 666},
#  {'step_num': 667},
#  {'step_num': 668},
#  {'step_num': 669},
#  {'step_num': 670},
#  {'step_num': 671},
#  {'Renderer': {'image_filename': './foreground_00672.png',
#    'time_stamp': datetime.datetime(2015, 1, 8, 0, 0)},
#   'step_num': 672,
#   'valid': True},
#  {'step_num': 673},
#  {'step_num': 674},
#  {'step_num': 675},
#  {'step_num': 676},
#  {'step_num': 677},
#  {'step_num': 678},
#  {'step_num': 679},
#  {'step_num': 680},
#  {'step_num': 681},
#  {'step_num': 682},
#  {'step_num': 683},
#  {'step_num': 684},
#  {'step_num': 685},
#  {'step_num': 686},
#  {'step_num': 687},
#  {'step_num': 688},
#  {'step_num': 689},
#  {'step_num': 690},
#  {'step_num': 691},
#  {'step_num': 692},
#  {'step_num': 693},
#  {'step_num': 694},
#  {'step_num': 695},
#  {'Renderer': {'image_filename': './foreground_00696.png',
#    'time_stamp': datetime.datetime(2015, 1, 8, 6, 0)},
#   'step_num': 696,
#   'valid': True},
#  {'step_num': 697},
#  {'step_num': 698},
#  {'step_num': 699},
#  {'step_num': 700},
#  {'step_num': 701},
#  {'step_num': 702},
#  {'step_num': 703},
#  {'step_num': 704},
#  {'step_num': 705},
#  {'step_num': 706},
#  {'step_num': 707},
#  {'step_num': 708},
#  {'step_num': 709},
#  {'step_num': 710},
#  {'step_num': 711},
#  {'step_num': 712},
#  {'step_num': 713},
#  {'step_num': 714},
#  {'step_num': 715},
#  {'step_num': 716},
#  {'step_num': 717},
#  {'step_num': 718},
#  {'step_num': 719},
#  {'Renderer': {'image_filename': './foreground_00720.png',
#    'time_stamp': datetime.datetime(2015, 1, 8, 12, 0)},
#   'step_num': 720,
#   'valid': True},
#  {'step_num': 721},
#  {'step_num': 722},
#  {'step_num': 723},
#  {'step_num': 724},
#  {'step_num': 725},
#  {'step_num': 726},
#  {'step_num': 727},
#  {'step_num': 728},
#  {'step_num': 729},
#  {'step_num': 730},
#  {'step_num': 731},
#  {'step_num': 732},
#  {'step_num': 733},
#  {'step_num': 734},
#  {'step_num': 735},
#  {'step_num': 736},
#  {'step_num': 737},
#  {'step_num': 738},
#  {'step_num': 739},
#  {'step_num': 740},
#  {'step_num': 741},
#  {'step_num': 742},
#  {'step_num': 743},
#  {'Renderer': {'image_filename': './foreground_00744.png',
#    'time_stamp': datetime.datetime(2015, 1, 8, 18, 0)},
#   'step_num': 744,
#   'valid': True},
#  {'step_num': 745},
#  {'step_num': 746},
#  {'step_num': 747},
#  {'step_num': 748},
#  {'step_num': 749},
#  {'step_num': 750},
#  {'step_num': 751},
#  {'step_num': 752},
#  {'step_num': 753},
#  {'step_num': 754},
#  {'step_num': 755},
#  {'step_num': 756},
#  {'step_num': 757},
#  {'step_num': 758},
#  {'step_num': 759},
#  {'step_num': 760},
#  {'step_num': 761},
#  {'step_num': 762},
#  {'step_num': 763},
#  {'step_num': 764},
#  {'step_num': 765},
#  {'step_num': 766},
#  {'step_num': 767},
#  {'Renderer': {'image_filename': './foreground_00768.png',
#    'time_stamp': datetime.datetime(2015, 1, 9, 0, 0)},
#   'step_num': 768,
#   'valid': True},
#  {'step_num': 769},
#  {'step_num': 770},
#  {'step_num': 771},
#  {'step_num': 772},
#  {'step_num': 773},
#  {'step_num': 774},
#  {'step_num': 775},
#  {'step_num': 776},
#  {'step_num': 777},
#  {'step_num': 778},
#  {'step_num': 779},
#  {'step_num': 780},
#  {'step_num': 781},
#  {'step_num': 782},
#  {'step_num': 783},
#  {'step_num': 784},
#  {'step_num': 785},
#  {'step_num': 786},
#  {'step_num': 787},
#  {'step_num': 788},
#  {'step_num': 789},
#  {'step_num': 790},
#  {'step_num': 791},
#  {'Renderer': {'image_filename': './foreground_00792.png',
#    'time_stamp': datetime.datetime(2015, 1, 9, 6, 0)},
#   'step_num': 792,
#   'valid': True},
#  {'step_num': 793},
#  {'step_num': 794},
#  {'step_num': 795},
#  {'step_num': 796},
#  {'step_num': 797},
#  {'step_num': 798},
#  {'step_num': 799},
#  {'step_num': 800},
#  {'step_num': 801},
#  {'step_num': 802},
#  {'step_num': 803},
#  {'step_num': 804},
#  {'step_num': 805},
#  {'step_num': 806},
#  {'step_num': 807},
#  {'step_num': 808},
#  {'step_num': 809},
#  {'step_num': 810},
#  {'step_num': 811},
#  {'step_num': 812},
#  {'step_num': 813},
#  {'step_num': 814},
#  {'step_num': 815},
#  {'Renderer': {'image_filename': './foreground_00816.png',
#    'time_stamp': datetime.datetime(2015, 1, 9, 12, 0)},
#   'step_num': 816,
#   'valid': True},
#  {'step_num': 817},
#  {'step_num': 818},
#  {'step_num': 819},
#  {'step_num': 820},
#  {'step_num': 821},
#  {'step_num': 822},
#  {'step_num': 823},
#  {'step_num': 824},
#  {'step_num': 825},
#  {'step_num': 826},
#  {'step_num': 827},
#  {'step_num': 828},
#  {'step_num': 829},
#  {'step_num': 830},
#  {'step_num': 831},
#  {'step_num': 832},
#  {'step_num': 833},
#  {'step_num': 834},
#  {'step_num': 835},
#  {'step_num': 836},
#  {'step_num': 837},
#  {'step_num': 838},
#  {'step_num': 839},
#  {'Renderer': {'image_filename': './foreground_00840.png',
#    'time_stamp': datetime.datetime(2015, 1, 9, 18, 0)},
#   'step_num': 840,
#   'valid': True},
#  {'step_num': 841},
#  {'step_num': 842},
#  {'step_num': 843},
#  {'step_num': 844},
#  {'step_num': 845},
#  {'step_num': 846},
#  {'step_num': 847},
#  {'step_num': 848},
#  {'step_num': 849},
#  {'step_num': 850},
#  {'step_num': 851},
#  {'step_num': 852},
#  {'step_num': 853},
#  {'step_num': 854},
#  {'step_num': 855},
#  {'step_num': 856},
#  {'step_num': 857},
#  {'step_num': 858},
#  {'step_num': 859},
#  {'step_num': 860},
#  {'step_num': 861},
#  {'step_num': 862},
#  {'step_num': 863},
#  {'Renderer': {'image_filename': './foreground_00864.png',
#    'time_stamp': datetime.datetime(2015, 1, 10, 0, 0)},
#   'step_num': 864,
#   'valid': True},
#  {'step_num': 865},
#  {'step_num': 866},
#  {'step_num': 867},
#  {'step_num': 868},
#  {'step_num': 869},
#  {'step_num': 870},
#  {'step_num': 871},
#  {'step_num': 872},
#  {'step_num': 873},
#  {'step_num': 874},
#  {'step_num': 875},
#  {'step_num': 876},
#  {'step_num': 877},
#  {'step_num': 878},
#  {'step_num': 879},
#  {'step_num': 880},
#  {'step_num': 881},
#  {'step_num': 882},
#  {'step_num': 883},
#  {'step_num': 884},
#  {'step_num': 885},
#  {'step_num': 886},
#  {'step_num': 887},
#  {'Renderer': {'image_filename': './foreground_00888.png',
#    'time_stamp': datetime.datetime(2015, 1, 10, 6, 0)},
#   'step_num': 888,
#   'valid': True},
#  {'step_num': 889},
#  {'step_num': 890},
#  {'step_num': 891},
#  {'step_num': 892},
#  {'step_num': 893},
#  {'step_num': 894},
#  {'step_num': 895},
#  {'step_num': 896},
#  {'step_num': 897},
#  {'step_num': 898},
#  {'step_num': 899},
#  {'step_num': 900},
#  {'step_num': 901},
#  {'step_num': 902},
#  {'step_num': 903},
#  {'step_num': 904},
#  {'step_num': 905},
#  {'step_num': 906},
#  {'step_num': 907},
#  {'step_num': 908},
#  {'step_num': 909},
#  {'step_num': 910},
#  {'step_num': 911},
#  {'Renderer': {'image_filename': './foreground_00912.png',
#    'time_stamp': datetime.datetime(2015, 1, 10, 12, 0)},
#   'step_num': 912,
#   'valid': True},
#  {'step_num': 913},
#  {'step_num': 914},
#  {'step_num': 915},
#  {'step_num': 916},
#  {'step_num': 917},
#  {'step_num': 918},
#  {'step_num': 919},
#  {'step_num': 920},
#  {'step_num': 921},
#  {'step_num': 922},
#  {'step_num': 923},
#  {'step_num': 924},
#  {'step_num': 925},
#  {'step_num': 926},
#  {'step_num': 927},
#  {'step_num': 928},
#  {'step_num': 929},
#  {'step_num': 930},
#  {'step_num': 931},
#  {'step_num': 932},
#  {'step_num': 933},
#  {'step_num': 934},
#  {'step_num': 935},
#  {'Renderer': {'image_filename': './foreground_00936.png',
#    'time_stamp': datetime.datetime(2015, 1, 10, 18, 0)},
#   'step_num': 936,
#   'valid': True},
#  {'step_num': 937},
#  {'step_num': 938},
#  {'step_num': 939},
#  {'step_num': 940},
#  {'step_num': 941},
#  {'step_num': 942},
#  {'step_num': 943},
#  {'step_num': 944},
#  {'step_num': 945},
#  {'step_num': 946},
#  {'step_num': 947},
#  {'step_num': 948},
#  {'step_num': 949},
#  {'step_num': 950},
#  {'step_num': 951},
#  {'step_num': 952},
#  {'step_num': 953},
#  {'step_num': 954},
#  {'step_num': 955},
#  {'step_num': 956},
#  {'step_num': 957},
#  {'step_num': 958},
#  {'step_num': 959},
#  {'Renderer': {'image_filename': './foreground_00960.png',
#    'time_stamp': datetime.datetime(2015, 1, 11, 0, 0)},
#   'step_num': 960,
#   'valid': True}]
